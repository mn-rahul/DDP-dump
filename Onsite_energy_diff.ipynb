# %%
import pandas as pd
import numpy as np

# %%
data=data=pd.read_csv('Data/13000_triv_nontriv_spdf_binary.csv')
pt=pd.read_csv('Data/PeriodicTablesdpf.csv')

# %%
pt.head()
# Out:
#      Element Symbol  NumberofElectrons  s  p  d  f   sv   pv   dv  ...  Phase  \
# 0   Hydrogen      H                  1  1  0  0  0  1.0  0.0  0.0  ...    gas
# 1     Helium     He                  2  2  0  0  0  2.0  0.0  0.0  ...    gas
# 2    Lithium     Li                  3  3  0  0  0  1.0  0.0  0.0  ...  solid
# 3  Beryllium     Be                  4  4  0  0  0  2.0  0.0  0.0  ...  solid
# 4      Boron      B                  5  4  1  0  0  2.0  1.0  0.0  ...  solid
#
#    Metal  Nonmetal  Metalloid  AtomicRadius  Electronegativity  \
# 0    NaN       yes        NaN          0.79               2.20
# 1    NaN       yes        NaN          0.49                NaN
# 2    yes       NaN        NaN          2.10               0.98
# 3    yes       NaN        NaN          1.40               1.57
# 4    NaN       NaN        yes          1.20               2.04
#
#   FirstIonization   Density NumberofShells NumberofValence
# ...

# %%
E1_dict = dict(zip(pt['Symbol'],pt['E1']))

# %%
E2_dict = dict(zip(pt['Symbol'],pt['E2']))

# %%
data.head()
# Out:
#    NoE Stoich. Formula  SG Point Group  Top_Class  \
# 0  252       YCu(WO4)2   1          C1          0
# 1  144          TeSeO4   1          C1          0
# 2  208   SrCaB5H2ClO10   1          C1          0
# 3  104         Si4P4Ru   1          C1          0
# 4  128         Si3P2Pt   1          C1          0
#
#                                                split  \
# 0  ['Y', 'Cu', 'W', 'O', 'O', 'O', 'O', 'W', 'O',...
# 1                   ['Te', 'Se', 'O', 'O', 'O', 'O']
# 2  ['Sr', 'Ca', 'B', 'B', 'B', 'B', 'B', 'H', 'H'...
# 3  ['Si', 'Si', 'Si', 'Si', 'P', 'P', 'P', 'P', '...
# 4                 ['Si', 'Si', 'Si', 'P', 'P', 'Pt']
#
#                                          feat_vector  s_bin  p_bin  d_bin  \
# 0  [2.0, 0.0, 2.6666666666666665, 1.8856180831641...      1      1      1
# 1  [2.0, 0.0, 4.0, 0.0, 3.3333333333333335, 4.714...      1      1      1
# 2  [1.9, 0.3, 2.5, 1.8027756377319946, 0.0, 0.0, ...      1      1      0
# ...

# %%
comp=data['split']

# %%
comp[1][1]
# Out:
# "'"
