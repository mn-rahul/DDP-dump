# %%
import pandas as pd
import csv
import numpy as np
import os

# %%
# os.chdir("../data")
uncd=pd.read_csv('Data/unclass.csv')
cld=pd.read_csv('Data/class.csv')

# %%
uncd.head()
# Out:
#       Formula Source       ID space group  centered  natoms  nelectrons  dim  \
# 0   ZnH4(CO)4    COD  7012468      C2 (5)         0      13          56    3
# 1  VAg(PSe3)2   ICSD    68143      C2 (5)         0      10          70    2
# 2     VAgHgO4    COD  4308659      C2 (5)         0      14         120    3
# 3      V2ZnO6   ICSD    26998      C2 (5)         0       9          74    3
# 4     V2Pb3O8   ICSD    29359      C2 (5)         0      13         116    3
#
#    bandgap  directbandgap  metallicity        ν  wcc
# 0   5.1539          5.377        0.000  (0;000)    0
# 1   0.0000          0.007        0.288  (1;100)    1
# 2   0.9655          1.513        0.000  (0;000)    0
# 3   2.1247          2.204        0.000  (0;000)    0
# 4   2.3727          2.545        0.000  (0;000)    0

# %%
uncd = uncd.rename(columns={'ID': 'ICSD'})

# %%
cld.head()
# Out:
#      TQC      ICSD    NoE Stoich. Formula  SG  Top_Class  idx
# 0  2.2.1  202564.0   72.0           S1Ta6   2          2    1
# 1  2.2.2   41017.0  116.0           P3Tc2   2          2    2
# 2  2.2.3   66584.0  158.0            O9V5   2          2    3
# 3  2.2.4   80363.0  154.0         O9P3Ru1   2          2    4
# 4  2.2.5    2212.0  124.0            O7V4   2          2    5

# %%
# cld['ICSD']=cld['ICSD'].astype('int32')

# %%
import re
chem=uncd['Formula']
comp=[]
for i in range(len(chem)): 
    comp.append(re.findall('[A-Z][a-z]?|[0-9]+', chem[i]))

# %%
comp
# Out:
# [['Zn', 'H', '4', 'C', 'O', '4'],
#  ['V', 'Ag', 'P', 'Se', '3', '2'],
#  ['V', 'Ag', 'Hg', 'O', '4'],
#  ['V', '2', 'Zn', 'O', '6'],
#  ['V', '2', 'Pb', '3', 'O', '8'],
#  ['V', '2', 'Pb', '3', 'O', '8'],
#  ['V', '2', 'Pb', '3', 'O', '8'],
#  ['V', '2', 'Pb', '3', 'O', '8'],
#  ['Tl', 'V', '5', 'S', '8'],
#  ['Tl', '2', 'C', '3', 'O', '4'],
#  ['Ta', 'As', '2'],
#  ['Ta', '2', 'Tl', '3', 'Cu', '3', 'S', '8'],
#  ['Ta', '2', 'O', '5'],
#  ['Sn', 'H', '2', 'N', '2', 'O', '3', 'F', '2'],
#  ['Si', 'O', '2'],
#  ['Si', 'O', '2'],
#  ['Si', 'O', '2'],
#  ['Si', '2', 'Cu', '4', 'Ni', 'S', '7'],
#  ['Sc', 'Bi', 'O', '3'],
#  ['Rb', 'V', 'P', '2', 'S', '7'],
#  ['Rb', 'Cu', 'Cl', '3'],
#  ['Rb', 'Cr', 'I', '3'],
#  ['Rb', 'Au', 'I', 'O', '3', '4'],
#  ['Rb', '4', 'C', 'O', '4'],
#  ['Rb', '4', 'C', 'O', '4'],
#  ['Pd', '5', 'Pb', '3'],
#  ['Pb', 'S'],
#  ['Os', 'O', '4'],
#  ['Ni', '5', 'Sb', '2'],
#  ['Ni', '5', 'Ge', '3'],
#  ['Nb', 'Tl', 'Br', '4', 'O'],
#  ['Nb', 'I', '3', 'O'],
# ...

# %%
len(comp)==len(uncd['Formula'])
# Out:
# True

# %%
uncd['composition']=comp

# %%
uncd.head()
# Out:
#       Formula Source     ICSD space group  centered  natoms  nelectrons  dim  \
# 0   ZnH4(CO)4    COD  7012468      C2 (5)         0      13          56    3
# 1  VAg(PSe3)2   ICSD    68143      C2 (5)         0      10          70    2
# 2     VAgHgO4    COD  4308659      C2 (5)         0      14         120    3
# 3      V2ZnO6   ICSD    26998      C2 (5)         0       9          74    3
# 4     V2Pb3O8   ICSD    29359      C2 (5)         0      13         116    3
#
#    bandgap  directbandgap  metallicity        ν  wcc           composition
# 0   5.1539          5.377        0.000  (0;000)    0   [Zn, H, 4, C, O, 4]
# 1   0.0000          0.007        0.288  (1;100)    1  [V, Ag, P, Se, 3, 2]
# 2   0.9655          1.513        0.000  (0;000)    0     [V, Ag, Hg, O, 4]
# 3   2.1247          2.204        0.000  (0;000)    0      [V, 2, Zn, O, 6]
# 4   2.3727          2.545        0.000  (0;000)    0   [V, 2, Pb, 3, O, 8]

# %%
pertable = pd.read_csv('Data/Periodic Table of Elements.csv')

# %%
pertable.head(20)
# Out:
#     AtomicNumber     Element Symbol  AtomicMass  NumberofNeutrons  \
# 0              1    Hydrogen      H       1.007                 0
# 1              2      Helium     He       4.002                 2
# 2              3     Lithium     Li       6.941                 4
# 3              4   Beryllium     Be       9.012                 5
# 4              5       Boron      B      10.811                 6
# 5              6      Carbon      C      12.011                 6
# 6              7    Nitrogen      N      14.007                 7
# 7              8      Oxygen      O      15.999                 8
# 8              9    Fluorine      F      18.998                10
# 9             10        Neon     Ne      20.180                10
# 10            11      Sodium     Na      22.990                12
# 11            12   Magnesium     Mg      24.305                12
# 12            13    Aluminum     Al      26.982                14
# ...

# %%
pertable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AtomicNumber       118 non-null    int64
#  1   Element            118 non-null    object
#  2   Symbol             118 non-null    object
#  3   AtomicMass         118 non-null    float64
#  4   NumberofNeutrons   118 non-null    int64
#  5   NumberofProtons    118 non-null    int64
#  6   NumberofElectrons  118 non-null    int64
#  7   Period             118 non-null    int64
#  8   Group              90 non-null     float64
#  9   Phase              118 non-null    object
#  10  Radioactive        37 non-null     object
#  11  Natural            90 non-null     object
#  12  Metal              92 non-null     object
#  13  Nonmetal           19 non-null     object
#  14  Metalloid          7 non-null      object
#  15  Type               115 non-null    object
# ...

# %%
pertable.drop(['Radioactive','Natural','Discoverer','Year'],axis=1)
# Out:
#      AtomicNumber      Element Symbol  AtomicMass  NumberofNeutrons  \
# 0               1     Hydrogen      H       1.007                 0
# 1               2       Helium     He       4.002                 2
# 2               3      Lithium     Li       6.941                 4
# 3               4    Beryllium     Be       9.012                 5
# 4               5        Boron      B      10.811                 6
# ..            ...          ...    ...         ...               ...
# 113           114    Flerovium     Fl     289.000               175
# 114           115    Moscovium     Mc     288.000               173
# 115           116  Livermorium     Lv     292.000               176
# 116           117   Tennessine     Ts     295.000               178
# 117           118    Oganesson     Og     294.000               176
#
#      NumberofProtons  NumberofElectrons  Period  Group       Phase  ...  \
# 0                  1                  1       1    1.0         gas  ...
# ...

# %%
j=comp[1]

# %%
j[1]
# Out:
# 'Ag'

# %%
j
# Out:
# ['V', 'Ag', 'P', 'Se', '3', '2']

# %%
weightedavg
